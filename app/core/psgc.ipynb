# %%
import json
from barangays import ph_barangays

# %%
print(ph_barangays)
# Out:
# [('02801001', 'Adams (Pob.)'), ('02802001', 'Bani'), ('02802002', 'Buyon'), ('02802003', 'Cabaruan'), ('02802004', 'Cabulalaan'), ('02802005', 'Cabusligan'), ('02802006', 'Cadaratan'), ('02802007', 'Calioet-Libong'), ('02802008', 'Casilian'), ('02802009', 'Corocor'), ('02802011', 'Duripes'), ('02802012', 'Ganagan'), ('02802013', 'Libtong'), ('02802014', 'Macupit'), ('02802015', 'Nambaran'), ('02802016', 'Natba'), ('02802017', 'Paninaan'), ('02802018', 'Pasiocan'), ('02802019', 'Pasngal'), ('02802020', 'Pipias'), ('02802021', 'Pulangi'), ('02802022', 'Pungto'), ('02802024', 'San Agustin I (Pob.)'), ('02802025', 'San Agustin II (Pob.)'), ('02802027', 'San Andres I (Pob.)'), ('02802028', 'San Andres II (Pob.)'), ('02802030', 'San Gabriel I (Pob.)'), ('02802031', 'San Gabriel II (Pob.)'), ('02802033', 'San Pedro I (Pob.)'), ('02802034', 'San Pedro II (Pob.)'), ('02802036', 'San Roque I (Pob.)'), ('02802037', 'San Roque II (Pob.)'), ('02802039', 'San Simon I (Pob.)'), ('02802040', 'San Si
# ...
